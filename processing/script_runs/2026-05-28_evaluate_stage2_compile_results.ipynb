# %% [markdown]
# # Assemble Stage 2 evaluation table after per-target SNR jobs finish

# %% [markdown]
# Note that you will need to start the kernel in the main working directory of the repo so imports and relative file paths work. If working in an IDE, this might mean configuring IDE settings.

# %%
##%% rename ava_test files
import paths
import os

files = sorted(paths.data_targets.rglob('*ava_test*'))
for file in files:
    newname = file.name.replace('_ava_test', '')
    os.rename(file, file.parent / newname)

# %%
import re
import os

import paths
os.chdir(paths.stage1_code)

import numpy as np
from tqdm import tqdm
from astropy import table
from astropy.table import Table, QTable
from astropy import units as u

import database_utilities as dbutils
import catalog_utilities as catutils

from processing import target_lists
from processing import preloads
from processing import transit_evaluation_utilities as tutils

# %%
# settings
sigma_threshold = 1

# %%
# targets
target_sets = [target_lists.eval_no(i) for i in range(1,4)]
targets = sum(target_sets, [])
drops = ['toi-4336a', 'hd21520', 'toi-6992', 'wasp-84', 'v1298tau'] # shouldn't need these in the future as I de-flagged them in the obsprog sheet
targets = set(targets) - set(drops)
targets = sorted(list(targets))

# %%
# paths
path_staging_area = paths.packages / '2026-03-10.stage2.eval3.staging_area'
path_planet_catalog = path_staging_area / 'planet_catalog_all_evals.ecsv'
path_host_catalog = path_staging_area / 'host_catalog_all_evals.ecsv'

# %%
##%% load catalogs

with catutils.catch_QTable_unit_warnings():
    planet_catalog = QTable.read(path_planet_catalog)
    host_catalog = QTable.read(path_host_catalog)

planet_catalog.add_index('tic_id')
host_catalog.add_index('tic_id')

# %%
##%% match in flags I (should not have) omitted when making eval catalog

with catutils.catch_QTable_unit_warnings():
    planet_catalog_current = preloads.planets.copy()
    newflags = [
        name for name in planet_catalog_current.colnames
        if 'flag_' in name and name not in planet_catalog.colnames
    ]
    planetcols_for_joining = planet_catalog_current[['id'] + newflags]
    planet_catalog = table.join(
        planet_catalog, planetcols_for_joining, keys='id', join_type='left',
    )

planet_catalog.add_index('tic_id')

# %%
def path_snrs(planet, host, tst_type):
    filenamer = tutils.FileNamer(tst_type, planet, host)
    return filenamer.snr_tbl_full

def load_snr_db(planet, host, tst_type):
    path = path_snrs(planet, host, tst_type)
    return tutils.DetectabilityDatabase.from_file(path)

def get_lya_flux(host):
    lya = host.lya_reconstruction
    Flya = np.trapz(lya.fluxes[0], lya.wavegrid_earth)
    return Flya

# %%
##%% QA settings

from datetime import datetime

N_CASE_DICT = {
    'eta': 4,
    'Tion': 4,
    'sw_ram_pressure_at_pl': 4,
    'sw_velocity': 3,
    'mass': 4,
    'time offset': 17,
    'lya reconstruction case': 5,
}
N_STIS_APERTURES = 4
N_COS_APERTURES = 1

STALE_CUTOFF = datetime(2026, 5, 1)  # user-adjustable each run
RUN_OFFSET_STATS_SMOKE_TEST = False  # True only when offset_stats smoke test is desired

# %%
##%% QA detection-sigmas tables

from processing.detection_sigmas_qa import (
    validate_all_targets,
    print_qa_report,
    qa_summary_table,
    planet_qa_reason,
    planet_cos_qa_reason,
    cos_metric_column_names,
    planet_key as snr_planet_key,
)

qa_issues, snr_excluded_planets, cos_incomplete_planets = validate_all_targets(
    sorted(targets),
    host_catalog,
    planet_catalog,
    stale_cutoff=STALE_CUTOFF,
    case_dict=N_CASE_DICT,
    n_stis_apertures=N_STIS_APERTURES,
    n_cos_apertures=N_COS_APERTURES,
    run_offset_stats_smoke_test=RUN_OFFSET_STATS_SMOKE_TEST,
    sigma_threshold=sigma_threshold,
)
print_qa_report(qa_issues)
print(f'\n{len(snr_excluded_planets)} planets excluded from SNR metrics')
print(f'{len(cos_incomplete_planets)} planets with incomplete COS exploration (STIS metrics kept)')
# Out:
# DS Tuc A b
#   [model] case_level_count: obs config missing entirely: offset=3.0, grating='g130m', aperture='psa', lya='low_2sig'; obs config missing entirely: offset=3.0, grating='g130m', aperture='psa', lya='low_1sig'; obs config missing entirely: offset=3.0, grating='g130m', aperture='psa', lya='high_2sig'; obs config missing entirely: offset=3.0, grating='g130m', aperture='psa', lya='high_1sig'
#     targets/ds-tuc-a/transit predictions/ds-tuc-a-b.outflow-tail-model.detection-sigmas.ecsv
#   [model] case_combinations_missing: 3072 of 40704 combinations missing; examples: eta=0.31622776601683794, Tion=0.33926588507858607, sw_ram_pressure_at_pl=7.25075054298438e-05, sw_velocity=200.00000000000003, mass=2.467504988000009e+30, time offset=3.0, grating='g130m', aperture='psa', lya reconstruction case='low_1sig'; eta=0.14677992676220694, Tion=0.9521819514126504, sw_ram_pressure_at_pl=0.0015621268498573061, sw_velocity=600.0, mass=2.467504988000009e+30, time offset=3.0, grating='g130m', aperture='psa', lya reconstruction case='high_1sig'; eta=0.06812920690579612, Tion=0.2025117909183106, sw_ram_pressure_at_pl=7.25075054298438e-05, sw_velocity=200.00000000000003, mass=2.467504988000009e+30, time offset=3.0, grating='g130m', aperture='psa', lya reconstruction case='low_1sig'
#     targets/ds-tuc-a/transit predictions/ds-tuc-a-b.outflow-tail-model.detection-sigmas.ecsv
#
# GJ 143 c
#   [model] case_level_count: obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='low_2sig'; obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='low_1sig'; obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='high_2sig'; obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='high_1sig'
#     targets/gj143/transit predictions/gj143-c.outflow-tail-model.detection-sigmas.ecsv
#   [model] case_combinations_missing: 3072 of 41472 combinations missing; examples: eta=0.14677992676220694, Tion=3.0381714863102127, sw_ram_pressure_at_pl=1.1207818109730422e-05, sw_velocity=600.0, mass=9.23677519216664e+27, time offset=1.0, grating='g130m', aperture='psa', lya reconstruction case='high_1sig'; eta=0.14677992676220694, Tion=6.930705050962624, sw_ram_pressure_at_pl=1.1207818109730422e-05, sw_velocity=200.00000000000003, mass=1.4286338906668483e+28, time offset=1.0, grating='g130m', aperture='psa', lya reconstruction case='low_2sig'; eta=0.03162277660168379, Tion=6.930705050962624, sw_ram_pressure_at_pl=5.202208338728781e-07, sw_velocity=200.00000000000003, mass=5.972000000000012e+27, time offset=1.0, grating='g130m', aperture='psa', lya reconstruction case='low_1sig'
#     targets/gj143/transit predictions/gj143-c.outflow-tail-model.detection-sigmas.ecsv
#
# GJ 3090 c
#   [model] column_mismatch: columns differ from reference (13 vs 13)
#     targets/gj3090/transit predictions/gj3090-c.outflow-tail-model.detection-sigmas.ecsv
#   [flat] column_mismatch: columns differ from reference (13 vs 13)
#     targets/gj3090/transit predictions/gj3090-c.simple-opaque-tail.detection-sigmas.ecsv
#
# GJ 3470 b
#   [model] case_level_count: obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='low_2sig'; obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='low_1sig'; obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='high_2sig'; obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='high_1sig'
#     targets/gj3470/transit predictions/gj3470-b.outflow-tail-model.detection-sigmas.ecsv
#   [model] case_combinations_missing: 3072 of 40704 combinations missing; examples: eta=0.06812920690579612, Tion=2.851499242341666, sw_ram_pressure_at_pl=0.0003575123272164765, sw_velocity=600.0, mass=7.534128663331138e+28, time offset=1.0, grating='g130m', aperture='psa', lya reconstruction case='high_2sig'; eta=0.31622776601683794, Tion=1.2277848597526915, sw_ram_pressure_at_pl=3.575123272164765e-06, sw_velocity=400.00000000000006, mass=7.534128663331138e+28, time offset=1.0, grating='g130m', aperture='psa', lya reconstruction case='high_2sig'; eta=0.06812920690579612, Tion=2.851499242341666, sw_ram_pressure_at_pl=7.702369598692068e-05, sw_velocity=200.00000000000003, mass=6.509479999999989e+28, time offset=1.0, grating='g130m', aperture='psa', lya reconstruction case='low_2sig'
#     targets/gj3470/transit predictions/gj3470-b.outflow-tail-model.detection-sigmas.ecsv
#
# GJ 486 b
#   [model] case_level_count: obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='low_2sig'; obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='low_1sig'; obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='high_2sig'; obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='high_1sig'
#     targets/gj486/transit predictions/gj486-b.outflow-tail-model.detection-sigmas.ecsv
#   [model] case_combinations_missing: 3072 of 40704 combinations missing; examples: eta=0.03162277660168379, Tion=16.78737132660505, sw_ram_pressure_at_pl=8.718847425231689e-07, sw_velocity=600.0, mass=1.7450183999999943e+28, time offset=1.0, grating='g130m', aperture='psa', lya reconstruction case='low_2sig'; eta=0.06812920690579612, Tion=1.532909093636114, sw_ram_pressure_at_pl=4.046930485092893e-06, sw_velocity=600.0, mass=1.6835572281492141e+28, time offset=1.0, grating='g130m', aperture='psa', lya reconstruction case='high_2sig'; eta=0.14677992676220694, Tion=7.559514970695922, sw_ram_pressure_at_pl=8.718847425231689e-07, sw_velocity=400.00000000000006, mass=1.62426077596285e+28, time offset=1.0, grating='g130m', aperture='psa', lya reconstruction case='low_1sig'
#     targets/gj486/transit predictions/gj486-b.outflow-tail-model.detection-sigmas.ecsv
#
# GJ 9827 c
#   [model] case_level_count: obs config missing entirely: offset=2.0, grating='g130m', aperture='psa', lya='low_2sig'; obs config missing entirely: offset=2.0, grating='g130m', aperture='psa', lya='low_1sig'; obs config missing entirely: offset=2.0, grating='g130m', aperture='psa', lya='high_2sig'; obs config missing entirely: offset=2.0, grating='g130m', aperture='psa', lya='high_1sig'
#     targets/gj9827/transit predictions/gj9827-c.outflow-tail-model.detection-sigmas.ecsv
#   [model] case_combinations_missing: 3072 of 40704 combinations missing; examples: eta=0.03162277660168379, Tion=20.20543409493686, sw_ram_pressure_at_pl=5.20775715500893e-07, sw_velocity=200.00000000000003, mass=6.449760000000022e+27, time offset=2.0, grating='g130m', aperture='psa', lya reconstruction case='low_2sig'; eta=0.14677992676220694, Tion=5.404030289002954, sw_ram_pressure_at_pl=1.1219772672012986e-05, sw_velocity=200.00000000000003, mass=6.449760000000022e+27, time offset=2.0, grating='g130m', aperture='psa', lya reconstruction case='low_1sig'; eta=0.31622776601683794, Tion=20.20543409493686, sw_ram_pressure_at_pl=5.2077571550089296e-05, sw_velocity=400.00000000000006, mass=8.644238722905838e+27, time offset=2.0, grating='g130m', aperture='psa', lya reconstruction case='low_2sig'
#     targets/gj9827/transit predictions/gj9827-c.outflow-tail-model.detection-sigmas.ecsv
#
# HD 110067 d
#   [model] case_level_count: obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='low_2sig'; obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='low_1sig'; obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='high_2sig'; obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='high_1sig'
#     targets/hd110067/transit predictions/hd110067-d.outflow-tail-model.detection-sigmas.ecsv
#   [model] case_combinations_missing: 3072 of 40704 combinations missing; examples: eta=0.06812920690579612, Tion=6.238711182393887, sw_ram_pressure_at_pl=3.2909128486102555e-07, sw_velocity=400.00000000000006, mass=1.206343999999999e+28, time offset=1.0, grating='g130m', aperture='psa', lya reconstruction case='high_2sig'; eta=0.06812920690579612, Tion=9.786171530908202, sw_ram_pressure_at_pl=7.090056802917577e-06, sw_velocity=400.00000000000006, mass=4.620129750209123e+28, time offset=1.0, grating='g130m', aperture='psa', lya reconstruction case='low_1sig'; eta=0.31622776601683794, Tion=9.786171530908202, sw_ram_pressure_at_pl=3.2909128486102555e-05, sw_velocity=400.00000000000006, mass=9.041607999999973e+28, time offset=1.0, grating='g130m', aperture='psa', lya reconstruction case='low_2sig'
#     targets/hd110067/transit predictions/hd110067-d.outflow-tail-model.detection-sigmas.ecsv
#
# HD 110067 e
#   [model] case_level_count: obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='low_2sig'; obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='low_1sig'; obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='high_2sig'; obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='high_1sig'
#     targets/hd110067/transit predictions/hd110067-e.outflow-tail-model.detection-sigmas.ecsv
#   [model] case_combinations_missing: 3072 of 40704 combinations missing; examples: eta=0.31622776601683794, Tion=16.80873574215381, sw_ram_pressure_at_pl=8.893256576642291e-07, sw_velocity=200.00000000000003, mass=5.972000000000012e+27, time offset=1.0, grating='g130m', aperture='psa', lya reconstruction case='high_2sig'; eta=0.03162277660168379, Tion=4.354930417177109, sw_ram_pressure_at_pl=1.9159940476072347e-07, sw_velocity=200.00000000000003, mass=5.972000000000012e+27, time offset=1.0, grating='g130m', aperture='psa', lya reconstruction case='high_2sig'; eta=0.06812920690579612, Tion=10.715615121324884, sw_ram_pressure_at_pl=1.9159940476072347e-07, sw_velocity=200.00000000000003, mass=1.4796631918060294e+28, time offset=1.0, grating='g130m', aperture='psa', lya reconstruction case='low_1sig'
#     targets/hd110067/transit predictions/hd110067-e.outflow-tail-model.detection-sigmas.ecsv
#
# HD 18599 b
#   [model] case_level_count: obs config missing entirely: offset=3.0, grating='g130m', aperture='psa', lya='low_2sig'; obs config missing entirely: offset=3.0, grating='g130m', aperture='psa', lya='low_1sig'; obs config missing entirely: offset=3.0, grating='g130m', aperture='psa', lya='high_2sig'; obs config missing entirely: offset=3.0, grating='g130m', aperture='psa', lya='high_1sig'
#     targets/hd18599/transit predictions/hd18599-b.outflow-tail-model.detection-sigmas.ecsv
#   [model] case_combinations_missing: 3072 of 40704 combinations missing; examples: eta=0.14677992676220694, Tion=0.2120428655159291, sw_ram_pressure_at_pl=0.00015727785896185126, sw_velocity=600.0, mass=5.972000000000012e+27, time offset=3.0, grating='g130m', aperture='psa', lya reconstruction case='low_1sig'; eta=0.31622776601683794, Tion=0.7951399576920225, sw_ram_pressure_at_pl=7.300191539318545e-06, sw_velocity=400.00000000000006, mass=1.7250121032722778e+28, time offset=3.0, grating='g130m', aperture='psa', lya reconstruction case='high_1sig'; eta=0.14677992676220694, Tion=0.2120428655159291, sw_ram_pressure_at_pl=0.00015727785896185126, sw_velocity=200.00000000000003, mass=5.972000000000012e+27, time offset=3.0, grating='g130m', aperture='psa', lya reconstruction case='high_2sig'
#     targets/hd18599/transit predictions/hd18599-b.outflow-tail-model.detection-sigmas.ecsv
#
# HD 207496 b
#   [model] case_level_count: obs config missing entirely: offset=2.0, grating='g130m', aperture='psa', lya='low_2sig'; obs config missing entirely: offset=2.0, grating='g130m', aperture='psa', lya='low_1sig'; obs config missing entirely: offset=2.0, grating='g130m', aperture='psa', lya='high_2sig'; obs config missing entirely: offset=2.0, grating='g130m', aperture='psa', lya='high_1sig'
#     targets/hd207496/transit predictions/hd207496-b.outflow-tail-model.detection-sigmas.ecsv
#   [model] case_combinations_missing: 3072 of 40704 combinations missing; examples: eta=0.31622776601683794, Tion=3.17495279233125, sw_ram_pressure_at_pl=0.0003298605229493467, sw_velocity=200.00000000000003, mass=1.99376065978179e+28, time offset=2.0, grating='g130m', aperture='psa', lya reconstruction case='high_1sig'; eta=0.31622776601683794, Tion=3.17495279233125, sw_ram_pressure_at_pl=0.0003298605229493467, sw_velocity=200.00000000000003, mass=3.642920000000008e+28, time offset=2.0, grating='g130m', aperture='psa', lya reconstruction case='low_2sig'; eta=0.03162277660168379, Tion=1.2261358238650477, sw_ram_pressure_at_pl=7.106629535141307e-05, sw_velocity=200.00000000000003, mass=5.972000000000012e+27, time offset=2.0, grating='g130m', aperture='psa', lya reconstruction case='high_2sig'
#     targets/hd207496/transit predictions/hd207496-b.outflow-tail-model.detection-sigmas.ecsv
#
# HD 209458 b
#   [model] case_level_count: obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='low_2sig'; obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='low_1sig'; obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='high_2sig'; obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='high_1sig'
#     targets/hd209458/transit predictions/hd209458-b.outflow-tail-model.detection-sigmas.ecsv
#   [model] case_combinations_missing: 3072 of 40704 combinations missing; examples: eta=0.14677992676220694, Tion=0.5198498785587232, sw_ram_pressure_at_pl=0.0001570834468193427, sw_velocity=400.00000000000006, mass=1.3276550885392433e+30, time offset=1.0, grating='g130m', aperture='psa', lya reconstruction case='low_1sig'; eta=0.06812920690579612, Tion=0.5198498785587232, sw_ram_pressure_at_pl=0.0001570834468193427, sw_velocity=400.00000000000006, mass=1.537445415599995e+30, time offset=1.0, grating='g130m', aperture='psa', lya reconstruction case='low_1sig'; eta=0.03162277660168379, Tion=7.137634030512502, sw_ram_pressure_at_pl=1.5708344681934271e-06, sw_velocity=200.00000000000003, mass=1.537445415599995e+30, time offset=1.0, grating='g130m', aperture='psa', lya reconstruction case='low_2sig'
#     targets/hd209458/transit predictions/hd209458-b.outflow-tail-model.detection-sigmas.ecsv
#
# HD 22946 d
#   [model] transit_sigma_invalid: 8320 values not finite and >= 0
#     targets/hd22946/transit predictions/hd22946-d.outflow-tail-model.detection-sigmas.ecsv
#
# HD 39091 c
#   [model] case_level_count: obs config missing entirely: offset=2.0, grating='g130m', aperture='psa', lya='low_2sig'; obs config missing entirely: offset=2.0, grating='g130m', aperture='psa', lya='low_1sig'; obs config missing entirely: offset=2.0, grating='g130m', aperture='psa', lya='high_2sig'; obs config missing entirely: offset=2.0, grating='g130m', aperture='psa', lya='high_1sig'
#     targets/hd39091/transit predictions/hd39091-c.outflow-tail-model.detection-sigmas.ecsv
#   [model] case_combinations_missing: 3072 of 40704 combinations missing; examples: eta=0.31622776601683794, Tion=25.979433281012483, sw_ram_pressure_at_pl=9.935825854165887e-07, sw_velocity=200.00000000000003, mass=2.2753948884136606e+28, time offset=2.0, grating='g130m', aperture='psa', lya reconstruction case='high_1sig'; eta=0.06812920690579612, Tion=1.1382406378008696, sw_ram_pressure_at_pl=4.611801833741753e-06, sw_velocity=400.00000000000006, mass=2.2753948884136606e+28, time offset=2.0, grating='g130m', aperture='psa', lya reconstruction case='low_2sig'; eta=0.03162277660168379, Tion=25.979433281012483, sw_ram_pressure_at_pl=9.935825854165887e-07, sw_velocity=400.00000000000006, mass=2.6217080000000078e+28, time offset=2.0, grating='g130m', aperture='psa', lya reconstruction case='low_1sig'
#     targets/hd39091/transit predictions/hd39091-c.outflow-tail-model.detection-sigmas.ecsv
#
# HD 63935 c
#   [model] case_level_count: obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='low_2sig'; obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='low_1sig'; obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='high_2sig'; obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='high_1sig'
#     targets/hd63935/transit predictions/hd63935-c.outflow-tail-model.detection-sigmas.ecsv
#   [model] case_combinations_missing: 3072 of 40704 combinations missing; examples: eta=0.14677992676220694, Tion=30.332217440191986, sw_ram_pressure_at_pl=5.299470490441381e-06, sw_velocity=400.00000000000006, mass=4.35956e+28, time offset=1.0, grating='g130m', aperture='psa', lya reconstruction case='high_2sig'; eta=0.06812920690579612, Tion=3.8025995980847664, sw_ram_pressure_at_pl=2.459796305249316e-07, sw_velocity=200.00000000000003, mass=9.017720000000006e+28, time offset=1.0, grating='g130m', aperture='psa', lya reconstruction case='high_2sig'; eta=0.31622776601683794, Tion=85.66747015547118, sw_ram_pressure_at_pl=1.1417363063407194e-06, sw_velocity=600.0, mass=9.017720000000006e+28, time offset=1.0, grating='g130m', aperture='psa', lya reconstruction case='high_2sig'
#     targets/hd63935/transit predictions/hd63935-c.outflow-tail-model.detection-sigmas.ecsv
#
# HD 73344 b
#   [model] case_level_count: obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='low_2sig'; obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='low_1sig'; obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='high_2sig'; obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='high_1sig'
#     targets/hd73344/transit predictions/hd73344-b.outflow-tail-model.detection-sigmas.ecsv
#   [model] case_combinations_missing: 3072 of 40704 combinations missing; examples: eta=0.31622776601683794, Tion=1.8762564526296213, sw_ram_pressure_at_pl=2.900569395776015e-05, sw_velocity=200.00000000000003, mass=6.258655999999979e+28, time offset=1.0, grating='g130m', aperture='psa', lya reconstruction case='high_1sig'; eta=0.14677992676220694, Tion=1.8762564526296213, sw_ram_pressure_at_pl=0.0001346325051855292, sw_velocity=200.00000000000003, mass=6.258655999999979e+28, time offset=1.0, grating='g130m', aperture='psa', lya reconstruction case='high_1sig'; eta=0.03162277660168379, Tion=0.9663002900814909, sw_ram_pressure_at_pl=6.249087327104667e-06, sw_velocity=600.0, mass=2.8599645775360745e+28, time offset=1.0, grating='g130m', aperture='psa', lya reconstruction case='low_1sig'
#     targets/hd73344/transit predictions/hd73344-b.outflow-tail-model.detection-sigmas.ecsv
#
# HIP 94235 b
#   [model] transit_sigma_invalid: 10260 values not finite and >= 0
#     targets/hip94235/transit predictions/hip94235-b.outflow-tail-model.detection-sigmas.ecsv
#
# K2-136 d
#   [model] case_level_count: obs config missing entirely: offset=2.0, grating='g130m', aperture='psa', lya='low_2sig'; obs config missing entirely: offset=2.0, grating='g130m', aperture='psa', lya='low_1sig'; obs config missing entirely: offset=2.0, grating='g130m', aperture='psa', lya='high_2sig'; obs config missing entirely: offset=2.0, grating='g130m', aperture='psa', lya='high_1sig'
#     targets/k2-136/transit predictions/k2-136-d.outflow-tail-model.detection-sigmas.ecsv
#   [model] case_combinations_missing: 3072 of 40704 combinations missing; examples: eta=0.06812920690579612, Tion=23.518139049209125, sw_ram_pressure_at_pl=6.935927610070659e-06, sw_velocity=200.00000000000003, mass=1.2422260591266033e+28, time offset=2.0, grating='g130m', aperture='psa', lya reconstruction case='low_2sig'; eta=0.31622776601683794, Tion=1.1739406986826664, sw_ram_pressure_at_pl=6.935927610070659e-06, sw_velocity=400.00000000000006, mass=1.7916000000000044e+28, time offset=2.0, grating='g130m', aperture='psa', lya reconstruction case='low_2sig'; eta=0.14677992676220694, Tion=1.1739406986826664, sw_ram_pressure_at_pl=6.935927610070659e-06, sw_velocity=400.00000000000006, mass=1.2422260591266033e+28, time offset=2.0, grating='g130m', aperture='psa', lya reconstruction case='high_2sig'
#     targets/k2-136/transit predictions/k2-136-d.outflow-tail-model.detection-sigmas.ecsv
#
# L 98-59 b
#   [model] case_level_count: obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='low_2sig'; obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='low_1sig'; obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='high_2sig'; obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='high_1sig'
#     targets/l98-59/transit predictions/l98-59-b.outflow-tail-model.detection-sigmas.ecsv
#   [model] case_combinations_missing: 3072 of 41472 combinations missing; examples: eta=0.06812920690579612, Tion=14.725502143141485, sw_ram_pressure_at_pl=2.695607049373718e-05, sw_velocity=600.0, mass=2.8698739451475533e+27, time offset=1.0, grating='g130m', aperture='psa', lya reconstruction case='high_2sig'; eta=0.03162277660168379, Tion=8.56091698806195, sw_ram_pressure_at_pl=0.00012511899580180944, sw_velocity=400.00000000000006, mass=2.0281353327874999e+27, time offset=1.0, grating='g130m', aperture='psa', lya reconstruction case='high_1sig'; eta=0.03162277660168379, Tion=8.56091698806195, sw_ram_pressure_at_pl=1.2511899580180945e-06, sw_velocity=600.0, mass=2.8698739451475533e+27, time offset=1.0, grating='g130m', aperture='psa', lya reconstruction case='high_2sig'
#     targets/l98-59/transit predictions/l98-59-b.outflow-tail-model.detection-sigmas.ecsv
#
# L 98-59 c
#   [model] case_level_count: obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='low_2sig'; obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='low_1sig'; obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='high_2sig'; obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='high_1sig'
#     targets/l98-59/transit predictions/l98-59-c.outflow-tail-model.detection-sigmas.ecsv
#   [model] case_combinations_missing: 3072 of 41472 combinations missing; examples: eta=0.31622776601683794, Tion=9.556034109565198, sw_ram_pressure_at_pl=6.516524274178299e-07, sw_velocity=200.00000000000003, mass=1.2370155943851679e+28, time offset=1.0, grating='g130m', aperture='psa', lya reconstruction case='low_2sig'; eta=0.31622776601683794, Tion=5.5555602757613975, sw_ram_pressure_at_pl=1.4039425954724567e-05, sw_velocity=600.0, mass=1.1337625591640727e+28, time offset=1.0, grating='g130m', aperture='psa', lya reconstruction case='high_2sig'; eta=0.31622776601683794, Tion=5.5555602757613975, sw_ram_pressure_at_pl=1.4039425954724567e-05, sw_velocity=600.0, mass=1.2370155943851679e+28, time offset=1.0, grating='g130m', aperture='psa', lya reconstruction case='low_2sig'
#     targets/l98-59/transit predictions/l98-59-c.outflow-tail-model.detection-sigmas.ecsv
#
# TOI-2076 e
#   [model] case_level_count: obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='low_2sig'; obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='low_1sig'; obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='high_2sig'; obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='high_1sig'
#     targets/toi-2076/transit predictions/toi-2076-e.outflow-tail-model.detection-sigmas.ecsv
#   [model] case_combinations_missing: 3072 of 40704 combinations missing; examples: eta=0.31622776601683794, Tion=0.27437118148153306, sw_ram_pressure_at_pl=2.8867343495069583e-05, sw_velocity=600.0, mass=2.806840000000009e+28, time offset=1.0, grating='g130m', aperture='psa', lya reconstruction case='high_1sig'; eta=0.31622776601683794, Tion=0.12419956408825604, sw_ram_pressure_at_pl=0.00013399033922277946, sw_velocity=600.0, mass=5.972000000000012e+27, time offset=1.0, grating='g130m', aperture='psa', lya reconstruction case='high_1sig'; eta=0.14677992676220694, Tion=0.6061176283523729, sw_ram_pressure_at_pl=2.8867343495069583e-05, sw_velocity=600.0, mass=2.806840000000009e+28, time offset=1.0, grating='g130m', aperture='psa', lya reconstruction case='low_2sig'
#     targets/toi-2076/transit predictions/toi-2076-e.outflow-tail-model.detection-sigmas.ecsv
#
# TOI-2134 b
#   [model] case_level_count: obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='low_2sig'; obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='low_1sig'; obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='high_2sig'; obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='high_1sig'
#     targets/toi-2134/transit predictions/toi-2134-b.outflow-tail-model.detection-sigmas.ecsv
#   [model] case_combinations_missing: 3072 of 40704 combinations missing; examples: eta=0.14677992676220694, Tion=43.82341737325642, sw_ram_pressure_at_pl=2.9357010980722385e-07, sw_velocity=400.00000000000006, mass=6.3840680000000105e+28, time offset=1.0, grating='g130m', aperture='psa', lya reconstruction case='low_1sig'; eta=0.14677992676220694, Tion=43.82341737325642, sw_ram_pressure_at_pl=1.3626317435636874e-06, sw_velocity=200.00000000000003, mass=5.089816656659055e+28, time offset=1.0, grating='g130m', aperture='psa', lya reconstruction case='low_2sig'; eta=0.06812920690579612, Tion=4.159282009752834, sw_ram_pressure_at_pl=6.3247762852515225e-06, sw_velocity=400.00000000000006, mass=4.5446919999999895e+28, time offset=1.0, grating='g130m', aperture='psa', lya reconstruction case='low_2sig'
#     targets/toi-2134/transit predictions/toi-2134-b.outflow-tail-model.detection-sigmas.ecsv
#
# TOI-2134 c
#   [model] case_level_count: obs config missing entirely: offset=9.0, grating='g130m', aperture='psa', lya='low_2sig'; obs config missing entirely: offset=9.0, grating='g130m', aperture='psa', lya='high_2sig'; obs config missing entirely: offset=9.0, grating='g130m', aperture='psa', lya='low_1sig'; obs config missing entirely: offset=9.0, grating='g130m', aperture='psa', lya='high_1sig'
#     targets/toi-2134/transit predictions/toi-2134-c.outflow-tail-model.detection-sigmas.ecsv
#   [model] case_combinations_missing: 3072 of 40704 combinations missing; examples: eta=0.31622776601683794, Tion=991.4363889994055, sw_ram_pressure_at_pl=6.023097425797164e-08, sw_velocity=400.00000000000006, mass=3.420164399999994e+29, time offset=9.0, grating='g130m', aperture='psa', lya reconstruction case='low_2sig'; eta=0.31622776601683794, Tion=452.2399215283792, sw_ram_pressure_at_pl=1.2976370035579151e-08, sw_velocity=400.00000000000006, mass=2.6363557766657747e+29, time offset=9.0, grating='g130m', aperture='psa', lya reconstruction case='high_1sig'; eta=0.14677992676220694, Tion=452.2399215283792, sw_ram_pressure_at_pl=1.2976370035579151e-08, sw_velocity=400.00000000000006, mass=2.0321747636338965e+29, time offset=9.0, grating='g130m', aperture='psa', lya reconstruction case='high_1sig'
#     targets/toi-2134/transit predictions/toi-2134-c.outflow-tail-model.detection-sigmas.ecsv
#
# TOI-2459 b
#   [model] case_level_count: obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='low_2sig'; obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='low_1sig'; obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='high_2sig'; obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='high_1sig'
#     targets/toi-2459/transit predictions/toi-2459-b.outflow-tail-model.detection-sigmas.ecsv
#   [model] case_combinations_missing: 3072 of 40704 combinations missing; examples: eta=0.06812920690579612, Tion=30.969688241442935, sw_ram_pressure_at_pl=3.1724695499119856e-07, sw_velocity=600.0, mass=7.915424595293836e+28, time offset=1.0, grating='g130m', aperture='psa', lya reconstruction case='high_1sig'; eta=0.03162277660168379, Tion=2.7945334170378566, sw_ram_pressure_at_pl=1.4725299237848028e-06, sw_velocity=600.0, mass=7.915424595293836e+28, time offset=1.0, grating='g130m', aperture='psa', lya reconstruction case='low_1sig'; eta=0.31622776601683794, Tion=103.0980845511231, sw_ram_pressure_at_pl=3.1724695499119854e-05, sw_velocity=200.00000000000003, mass=7.915424595293836e+28, time offset=1.0, grating='g130m', aperture='psa', lya reconstruction case='low_1sig'
#     targets/toi-2459/transit predictions/toi-2459-b.outflow-tail-model.detection-sigmas.ecsv
#
# TOI-480 b
#   [model] case_level_count: obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='low_2sig'; obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='low_1sig'; obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='high_2sig'; obs config missing entirely: offset=1.0, grating='g130m', aperture='psa', lya='high_1sig'
#     targets/toi-480/transit predictions/toi-480-b.outflow-tail-model.detection-sigmas.ecsv
#   [model] case_combinations_missing: 3072 of 40704 combinations missing; examples: eta=0.31622776601683794, Tion=1.4194401104383727, sw_ram_pressure_at_pl=1.3909580815208685e-06, sw_velocity=200.00000000000003, mass=7.405279999999993e+28, time offset=1.0, grating='g130m', aperture='psa', lya reconstruction case='low_2sig'; eta=0.31622776601683794, Tion=0.5157491190445305, sw_ram_pressure_at_pl=6.456255499210716e-06, sw_velocity=600.0, mass=9.896876696872444e+28, time offset=1.0, grating='g130m', aperture='psa', lya reconstruction case='low_2sig'; eta=0.03162277660168379, Tion=0.5157491190445305, sw_ram_pressure_at_pl=1.3909580815208685e-06, sw_velocity=200.00000000000003, mass=1.7677120000000043e+29, time offset=1.0, grating='g130m', aperture='psa', lya reconstruction case='low_2sig'
#     targets/toi-480/transit predictions/toi-480-b.outflow-tail-model.detection-sigmas.ecsv
#
# TOI-5169 01
#   [model] case_level_count: obs config missing entirely: offset=2.0, grating='g130m', aperture='psa', lya='low_2sig'; obs config missing entirely: offset=2.0, grating='g130m', aperture='psa', lya='low_1sig'; obs config missing entirely: offset=2.0, grating='g130m', aperture='psa', lya='high_2sig'; obs config missing entirely: offset=2.0, grating='g130m', aperture='psa', lya='high_1sig'
#     targets/toi-5169/transit predictions/toi-5169-01.outflow-tail-model.detection-sigmas.ecsv
#   [model] case_combinations_missing: 3072 of 40704 combinations missing; examples: eta=0.06812920690579612, Tion=1.4000280847958801, sw_ram_pressure_at_pl=6.984850583926883e-05, sw_velocity=600.0, mass=2.3296845773852686e+28, time offset=2.0, grating='g130m', aperture='psa', lya reconstruction case='high_1sig'; eta=0.14677992676220694, Tion=0.5085343900067875, sw_ram_pressure_at_pl=3.242080447480872e-06, sw_velocity=600.0, mass=1.0813437920231397e+28, time offset=2.0, grating='g130m', aperture='psa', lya reconstruction case='low_2sig'; eta=0.31622776601683794, Tion=1.4000280847958801, sw_ram_pressure_at_pl=1.5048404402701536e-05, sw_velocity=200.00000000000003, mass=5.0191532703511185e+28, time offset=2.0, grating='g130m', aperture='psa', lya reconstruction case='low_1sig'
#     targets/toi-5169/transit predictions/toi-5169-01.outflow-tail-model.detection-sigmas.ecsv
#
# TOI-561 e
#   [model] transit_sigma_invalid: 6552 values not finite and >= 0
#     targets/toi-561/transit predictions/toi-561-e.outflow-tail-model.detection-sigmas.ecsv
#
# TOI-712 d
#   [model] transit_sigma_invalid: 320 values not finite and >= 0
#     targets/toi-712/transit predictions/toi-712-d.outflow-tail-model.detection-sigmas.ecsv
#
# TOI-904 c
#   [model] transit_sigma_invalid: 2752 values not finite and >= 0
#     targets/toi-904/transit predictions/toi-904-c.outflow-tail-model.detection-sigmas.ecsv
#
# 6 planets excluded from SNR metrics
# 22 planets with incomplete COS exploration (STIS metrics kept)

# %%
print(qa_summary_table(qa_issues) if qa_issues else 'QA summary: no issues')
# Out:
#           check           count
# ------------------------- -----
#          case_level_count    22
# case_combinations_missing    22
#           column_mismatch     2
#     transit_sigma_invalid     5

# %%
##%% assemble table of properties

lya_bins = (-150, -50, 50, 150) * u.km/u.s

eval_rows = []
targets = sorted(targets)
for target in tqdm(targets):
    host = tutils.Host(target, host_catalog, planet_catalog)
    for planet in host.planets:
        row = {}

        row['hostname'] = host.hostname
        row['planet'] = planet.stela_suffix
        pkey = snr_planet_key(host, planet)
        row['snr qa\nflag'] = pkey in snr_excluded_planets
        row['COS snr\nqa flag'] = pkey in cos_incomplete_planets
        if row['snr qa\nflag']:
            row['snr qa\nreason'] = planet_qa_reason(qa_issues, pkey)
        elif row['COS snr\nqa flag']:
            row['snr qa\nreason'] = planet_cos_qa_reason(qa_issues, pkey)
        else:
            row['snr qa\nreason'] = ''

        if not row['snr qa\nflag']:
            try:
                # region model snrs
                snr_db = load_snr_db(planet, host, 'model')
                slctd_offsets, det_fracs, max_snrs = snr_db.offset_stats(
                    sigma_threshold, min_sample_check=5**4)

                row['best safe\ntransit offset'] = slctd_offsets[1]
                row['best overall\ntransit offset'] = slctd_offsets[2]

                off_lbls = ['no', 'safe', 'best']
                stat_sets = zip(det_fracs, max_snrs, off_lbls)
                for det_frac, max_snr, off_lbl in stat_sets:
                    row[f'sim {off_lbl} offset \nmax snr'] = max_snr
                    row[f'sim {off_lbl} offset \nfrac w snr > {sigma_threshold}'] = det_frac

                row['sim\nbest aperture'] = snr_db.meta['best base grating aperture']

                cos = snr_db.meta['COS considered']
                row['COS\nconsidered?'] = cos
                if cos and not row['COS snr\nqa flag']:
                    cos_snrs = snr_db.filter_obs_config(
                        grating='g130m', aperture='psa', offset='best safe')
                    cos_snrs = cos_snrs.clean_duplicates()
                    cosfrac, maxcossnr = cos_snrs.det_frac_and_max_snr(sigma_threshold)
                    row['sim COS safe offset\nmax snr'] = maxcossnr
                    row[f'sim COS safe offset\nfrac w snr > {sigma_threshold}'] = cosfrac
                    if det_fracs[1] > 0:
                        row['cos det\nfrac ratio'] = cosfrac / det_fracs[1]
                    row['cos snr\nratio'] = maxcossnr / max_snrs[1]
                elif cos and row['COS snr\nqa flag']:
                    for col in cos_metric_column_names(sigma_threshold):
                        row[col] = np.ma.masked

                row['H ionztn\ntime (h)'] = snr_db.geometric_mean_unique_tion_hours()

                # region flat transit
                snr_db_flat = load_snr_db(planet, host, 'flat')
                snr_db_flat = snr_db_flat.filter_obs_config(aperture='best', offset='best safe')
                snr_db_flat = snr_db_flat.clean_duplicates()
                flat_snr = snr_db_flat.median_case()['transit sigma']
                row['flat transit\nsnr'] = flat_snr
                row['flat transit\nbest aperture'] = snr_db_flat.meta['best base grating aperture']
            except Exception as exc:
                row['snr qa\nflag'] = True
                reason = f'compile_load_error: {exc}'
                if row['snr qa\nreason']:
                    row['snr qa\nreason'] = row['snr qa\nreason'] + '; ' + reason
                else:
                    row['snr qa\nreason'] = reason
                print(f'[{pkey}] SNR compile failed: {exc}')

        Flya = get_lya_flux(host)
        row['Lya Flux\n(erg s-1 cm-2)'] = Flya

        Mp = planet.params['pl_bmasse'].to_value('Mearth')
        Mp_err = 0.5 * (planet.params['pl_bmasseerr1'] - planet.params['pl_bmasseerr2'])
        Mp_prec = Mp_err / Mp
        if not np.isfinite(Mp_prec) or Mp_prec == 0:
            Mp_prec = np.ma.masked
        row['mass (Me)'] = Mp
        row['mass\nprecision'] = Mp_prec
        if planet.params['pl_bmassesrc'] == 'inferred from Rp':
            mass_source = 'M-R relationship'
        else:
            mass_source_rename = {'Mass': 'known', 'Msini': 'known', 'M-R relationship': 'M-R relationship'}
            mass_source = str(planet.params['pl_bmassprov'])
            mass_source = mass_source_rename[mass_source]
        row['mass\nsource'] = mass_source
        mass_flag = np.ma.masked
        if planet.params['pl_rade'] > 7 * u.Rearth:
            mass_flag = 'giant'
        if planet.params['flag_young']:
            mass_flag = 'young'
        row['mass\nflag'] = mass_flag

        row['radius (Re)'] = planet.params['pl_rade'].to_value('Rearth')
        row['orbital\nperiod (d)'] = planet.params['pl_orbper'].to_value('d')
        row['stellar\neff temp (K)'] = host.params['st_teff'].to_value('K')
        age = host.params['st_age'].to_value('Gyr')
        if not np.ma.is_masked(age):
            agelim_int = host.params['st_agelim']
            if not np.ma.is_masked(agelim_int):
                row['age\nlimit'] = catutils.limit_int2str[agelim_int]
            row['age (Gyr)'] = host.params['st_age'].to_value('Gyr')

        flag_cols = [name for name in planet_catalog.colnames if 'flag_' in name]
        for col in flag_cols:
            row[col] = planet.params[col]

        eval_rows.append(row)

# get column ordering from longest row
imax = np.argmax([len(row) for row in eval_rows])
ordered_cols = list(eval_rows[imax].keys())
for col in ('snr qa\nflag', 'snr qa\nreason'):
    if col in ordered_cols:
        ordered_cols.remove(col)
for i, col in enumerate(('snr qa\nflag', 'snr qa\nreason')):
    if col in eval_rows[imax]:
        ordered_cols.insert(2 + i, col)

eval_table = Table(rows=eval_rows)
eval_table = eval_table[ordered_cols]

eval_table['TIC'] = preloads.stela_names.loc['hostname', eval_table['hostname']]['tic_id']

# some grooming
for col in eval_table.colnames:
    if 'flag_' in col:
        eval_table[col] = eval_table[col].astype(bool)
formats_general = {
    'period': '.1f',
    'frac w': '.3f',
    'max snr': '.2f',
    'ratio': '.2f',
    'flux': '.1e',
    'radius': '.2f',
    'temp': '.0f',
    'ionztn': '.2f'
}
formats = {}
for substr, fmt in formats_general.items():
    for name in eval_table.colnames:
        if substr in name.lower():
            eval_table[name].format = fmt
            formats[name] = fmt
# Out:
# 100%|██████████| 124/124 [01:05<00:00,  1.89it/s]

# %%
##%% match in the catalog of escape detections

escape_detections = catutils.escape_catalog_merge_targets('download')

det_ids = np.char.add(escape_detections['Target Star'], escape_detections['Planet Letter'])
pcat_ids = np.char.add(planet_catalog['hostname'].astype(str),
                       dbutils.planet_suffixes(planet_catalog).astype(str))
eval_ids = np.char.add(eval_table['hostname'], eval_table['planet'])

# check to be sure names in escape detections match into planet catalog
suspect = ~np.isin(det_ids, pcat_ids)
if np.any(suspect):
    print("These names don't have a match in the planet catalog."
          "Note this could be do to cuts to planet catalog, such as requiring < 100 d periods (e.g., HD 136352d)."
          "Or because they aren't in the planet catalog your using to build the table (e.g. HAT-P-26 is not in any evals).")
    print(det_ids[suspect])

# match using name + letter
det_colnames = [name for name in escape_detections.colnames if 'detected' in name.lower()]
det_slim = escape_detections[det_colnames]
det_slim['temp'] = det_ids
eval_table['temp'] = eval_ids
eval_table = table.join(eval_table, det_slim, keys='temp', join_type='left')
eval_table.remove_column('temp')
# Out:
# These names don't have a match in the planet catalog.Note this could be do to cuts to planet catalog, such as requiring < 100 d periods (e.g., HD 136352d).Or because they aren't in the planet catalog your using to build the table (e.g. HAT-P-26 is not in any evals).
# ['HAT-P-26b' 'HIP 67522b' 'LTT 9779b' 'TOI-1268b' 'TOI-1728b' 'TOI-2136b'
#  'WASP-127b' 'WASP-52b' 'WASP-77 Ab']

# %%
##%% match in requested targets

files = list(paths.stage2_requests.glob('*.txt'))
path_check_table, = paths.selection_intermediates.glob('*pt1*.ecsv')
check_table = catutils.load_and_mask_ecsv(path_check_table)

def any_tois(planet_names):
    for name in planet_names:
        x = re.findall(r'TOI-\d+\.0\d', name)
        if x:
            return True
    return False

eval_table['TICletter'] = np.char.add( # temporary column for matchin
    eval_table['TIC'].astype(str),
    eval_table['planet']
)
check_table['TICletter'] = np.char.add( # temporary column for matching
    check_table['tic_id'].astype(str),
    check_table['pl_letter'].astype(str).filled('')
)
for file in files:
    requested_planets = catutils.read_requested_targets(file)
    if any_tois(requested_planets):
        raise NotImplementedError

    # match with TIC to ensure avoid misses
    hosts_letters = list(map(dbutils.split_hostname_planet_letter, requested_planets))
    hosts, letters = zip(*hosts_letters)
    tics = dbutils.query.query_simbad_for_tic_ids(hosts)
    tics_letters = np.char.add(tics, letters)

    # mark matches in a "requested" column
    request_name = 'requested\n' + requested_planets.name
    eval_table[request_name] = np.isin(eval_table['TICletter'], tics_letters)

    # print requested targets with no match in STELa tables
    not_in_list = ~np.isin(tics_letters, check_table['TICletter'])
    if np.any(not_in_list):
        print(f'\n{requested_planets.name} planets not matched to any planet known to STELa:')
        for name in requested_planets[not_in_list]:
            print(f'\n\t{name}')
        print('Consider checking that they are correctly named in the requested list txt file.')

eval_table.remove_column('TICletter')

# %%
##%% save table

# save csv to open in spreadsheet viewers
eval_filename = 'stage2_evaluation_metrics.csv'
eval_path = paths.catalogs / eval_filename
eval_table.write(eval_path, overwrite=True, formats=formats, fast_writer=False)

# save as an ecsv too for round tripping
eval_table_ecsv = eval_table.copy()
for name in eval_table_ecsv.colnames:
    eval_table_ecsv.rename_column(name, name.replace('\n', ' '))
eval_path_ecsv = paths.catalogs / eval_filename.replace('csv', 'ecsv')
eval_table_ecsv.write(eval_path_ecsv, overwrite=True)
